# %% [markdown]
# # **Computing $w(\theta)$ for a given cosmology and a set of redshift distributions**
#
# This notebook provides a step-by-step guide to calculate the theoretical angular correlation function $w(\theta)$ based on a given cosmology and redshift distributions.
#
# ---
#
# 1. **Full integrals**:
#    The code computes $w(\theta)$ without using simplifications like the Limber or flat-sky approximations.
#
# 2. **Parallel processing**:
#    By default, this notebook uses **128 CPUs** to speed up calculations.
#
# 3. **Optional no-wiggle template**:
#    You can generate a template without BAO wiggles to evaluate the significance of the BAO detection when running the BAO fits.
#
# ---

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from utils_template import TemplateInitializer, PowerSpectrumMultipoles, CorrelationFunctionMultipoles, WThetaCalculator

# 1. Arguments
class Args:
    def __init__(self):
        self.include_wiggles = "y"
        self.dataset = "DESIY1_LRG_Abacus"
        self.nz_flag = "mocks"
        # self.nz_flag = "clusteringz"
        self.cosmology_template = "desifid"
        self.base_path = None
# class Args:
#     def __init__(self):
#         self.include_wiggles = "n"
#         self.dataset = "DESY6"
#         self.nz_flag = "fid"
#         # self.nz_flag = "clusteringz"
#         self.cosmology_template = "planck"
#         self.base_path = None
# class Args:
#     def __init__(self):
#         self.include_wiggles = "y"
#         self.dataset = "DESY6_COLA"
#         self.nz_flag = "mocks"
#         self.cosmology_template = "mice"
#         self.base_path = None
args = Args()
args.include_wiggles = "" if args.include_wiggles == "y" else "_nowiggles"

# 2. Numerical resolution of the calculation. The larger these numbers are, the more accurate the template will be
Nk, Nmu, Nr, Nz, Ntheta = 2*10**5, 5*10**4, 5*10**4, 10**3, 10**3 # these are the settings I used for DES Y6 BAO
Nk, Nmu, Nr, Nz, Ntheta = 2*10**5, 5*10**4, 5*10**4, 10**2, 10**3 # for DESIY1_LRG_Abacus

# 3. Initialize the template
template_initializer = TemplateInitializer(
    include_wiggles=args.include_wiggles,
    dataset=args.dataset,
    nz_flag=args.nz_flag,
    cosmology_template=args.cosmology_template,
    Nk=Nk,
    Nmu=Nmu,
    Nr=Nr,
    Nz=Nz,
    Ntheta=Ntheta,
    verbose=True,
    use_multiprocessing=True,
    n_cpu=128,
    base_path=args.base_path,
)

# 4. Calculation of pk_ell
pk_calculator = PowerSpectrumMultipoles(
    template_initializer=template_initializer,
)
for bin_z in range(template_initializer.nbins):
    pk_calculator.compute_pk_ell(bin_z)

# 5. Calculation of xi_ell
xi_calculator = CorrelationFunctionMultipoles(
    template_initializer=template_initializer,
)
for bin_z in range(template_initializer.nbins):
    xi_calculator.compute_xi_ell(bin_z)

# 6. Calculation of w(theta)
wtheta_calculator = WThetaCalculator(
    template_initializer=template_initializer,
)
for bin_z in range(template_initializer.nbins):
    wtheta_calculator.compute_wtheta(bin_z)
# Out:
# Saving output to: /global/homes/j/jmena/BAOfit_wtheta/wtheta_template/DESIY1_LRG_Abacus/nz_mocks/wtheta_desifid
# Initialized cosmology: DESI fiducial.
# 0 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 0 - Pk_ell computed!
# 1 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 1 - Pk_ell computed!
# 2 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 2 - Pk_ell computed!
# 3 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 3 - Pk_ell computed!
# 4 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 4 - Pk_ell computed!
# 5 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 5 - Pk_ell computed!
# 6 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 6 - Pk_ell computed!
# 7 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 7 - Pk_ell computed!
# 8 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 8 - Pk_ell computed!
# 9 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 9 - Pk_ell computed!
# 10 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 10 - Pk_ell computed!
# 11 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 11 - Pk_ell computed!
# 12 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 12 - Pk_ell computed!
# 13 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 13 - Pk_ell computed!
# 14 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 14 - Pk_ell computed!
# 15 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 15 - Pk_ell computed!
# 16 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 16 - Pk_ell computed!
# 17 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 17 - Pk_ell computed!
# 18 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 18 - Pk_ell computed!
# 19 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 19 - Pk_ell computed!
# 20 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 20 - Pk_ell computed!
# 21 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 21 - Pk_ell computed!
# 22 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 22 - Pk_ell computed!
# 23 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 23 - Pk_ell computed!
# 24 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 24 - Pk_ell computed!
# 25 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 25 - Pk_ell computed!
# 26 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 26 - Pk_ell computed!
# 27 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 27 - Pk_ell computed!
# 28 - Computing Pk_ell...
# WARNING: P_ell(k) will be computed for all k values in parallel using 128 CPUs!
# 28 - Pk_ell computed!
# 0 - Attempting to load precomputed Pk_ell...
# 0 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 0 - xi_ell computed!
# 1 - Attempting to load precomputed Pk_ell...
# 1 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 1 - xi_ell computed!
# 2 - Attempting to load precomputed Pk_ell...
# 2 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 2 - xi_ell computed!
# 3 - Attempting to load precomputed Pk_ell...
# 3 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 3 - xi_ell computed!
# 4 - Attempting to load precomputed Pk_ell...
# 4 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 4 - xi_ell computed!
# 5 - Attempting to load precomputed Pk_ell...
# 5 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 5 - xi_ell computed!
# 6 - Attempting to load precomputed Pk_ell...
# 6 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 6 - xi_ell computed!
# 7 - Attempting to load precomputed Pk_ell...
# 7 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 7 - xi_ell computed!
# 8 - Attempting to load precomputed Pk_ell...
# 8 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 8 - xi_ell computed!
# 9 - Attempting to load precomputed Pk_ell...
# 9 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 9 - xi_ell computed!
# 10 - Attempting to load precomputed Pk_ell...
# 10 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 10 - xi_ell computed!
# 11 - Attempting to load precomputed Pk_ell...
# 11 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 11 - xi_ell computed!
# 12 - Attempting to load precomputed Pk_ell...
# 12 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 12 - xi_ell computed!
# 13 - Attempting to load precomputed Pk_ell...
# 13 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 13 - xi_ell computed!
# 14 - Attempting to load precomputed Pk_ell...
# 14 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 14 - xi_ell computed!
# 15 - Attempting to load precomputed Pk_ell...
# 15 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 15 - xi_ell computed!
# 16 - Attempting to load precomputed Pk_ell...
# 16 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 16 - xi_ell computed!
# 17 - Attempting to load precomputed Pk_ell...
# 17 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 17 - xi_ell computed!
# 18 - Attempting to load precomputed Pk_ell...
# 18 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 18 - xi_ell computed!
# 19 - Attempting to load precomputed Pk_ell...
# 19 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 19 - xi_ell computed!
# 20 - Attempting to load precomputed Pk_ell...
# 20 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 20 - xi_ell computed!
# 21 - Attempting to load precomputed Pk_ell...
# 21 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 21 - xi_ell computed!
# 22 - Attempting to load precomputed Pk_ell...
# 22 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 22 - xi_ell computed!
# 23 - Attempting to load precomputed Pk_ell...
# 23 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 23 - xi_ell computed!
# 24 - Attempting to load precomputed Pk_ell...
# 24 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 24 - xi_ell computed!
# 25 - Attempting to load precomputed Pk_ell...
# 25 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 25 - xi_ell computed!
# 26 - Attempting to load precomputed Pk_ell...
# 26 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 26 - xi_ell computed!
# 27 - Attempting to load precomputed Pk_ell...
# 27 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 27 - xi_ell computed!
# 28 - Attempting to load precomputed Pk_ell...
# 28 - Computing xi_ell...
# WARNING: xi_ell(r) will be computed for all r values in parallel using 128 CPUs!
# 28 - xi_ell computed!
# 0 - Attempting to load precomputed xi_ell...
# 0 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 0 - w(theta) computed!
# 1 - Attempting to load precomputed xi_ell...
# 1 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 1 - w(theta) computed!
# 2 - Attempting to load precomputed xi_ell...
# 2 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 2 - w(theta) computed!
# 3 - Attempting to load precomputed xi_ell...
# 3 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 3 - w(theta) computed!
# 4 - Attempting to load precomputed xi_ell...
# 4 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 4 - w(theta) computed!
# 5 - Attempting to load precomputed xi_ell...
# 5 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 5 - w(theta) computed!
# 6 - Attempting to load precomputed xi_ell...
# 6 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 6 - w(theta) computed!
# 7 - Attempting to load precomputed xi_ell...
# 7 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 7 - w(theta) computed!
# 8 - Attempting to load precomputed xi_ell...
# 8 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 8 - w(theta) computed!
# 9 - Attempting to load precomputed xi_ell...
# 9 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 9 - w(theta) computed!
# 10 - Attempting to load precomputed xi_ell...
# 10 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 10 - w(theta) computed!
# 11 - Attempting to load precomputed xi_ell...
# 11 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 11 - w(theta) computed!
# 12 - Attempting to load precomputed xi_ell...
# 12 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 12 - w(theta) computed!
# 13 - Attempting to load precomputed xi_ell...
# 13 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 13 - w(theta) computed!
# 14 - Attempting to load precomputed xi_ell...
# 14 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 14 - w(theta) computed!
# 15 - Attempting to load precomputed xi_ell...
# 15 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 15 - w(theta) computed!
# 16 - Attempting to load precomputed xi_ell...
# 16 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 16 - w(theta) computed!
# 17 - Attempting to load precomputed xi_ell...
# 17 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 17 - w(theta) computed!
# 18 - Attempting to load precomputed xi_ell...
# 18 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 18 - w(theta) computed!
# 19 - Attempting to load precomputed xi_ell...
# 19 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 19 - w(theta) computed!
# 20 - Attempting to load precomputed xi_ell...
# 20 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 20 - w(theta) computed!
# 21 - Attempting to load precomputed xi_ell...
# 21 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 21 - w(theta) computed!
# 22 - Attempting to load precomputed xi_ell...
# 22 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 22 - w(theta) computed!
# 23 - Attempting to load precomputed xi_ell...
# 23 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 23 - w(theta) computed!
# 24 - Attempting to load precomputed xi_ell...
# 24 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 24 - w(theta) computed!
# 25 - Attempting to load precomputed xi_ell...
# 25 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 25 - w(theta) computed!
# 26 - Attempting to load precomputed xi_ell...
# 26 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 26 - w(theta) computed!
# 27 - Attempting to load precomputed xi_ell...
# 27 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 27 - w(theta) computed!
# 28 - Attempting to load precomputed xi_ell...
# 28 - Computing w(theta)...
# WARNING: w(theta) will be computed for all theta values in parallel using 128 CPUs!
# 28 - w(theta) computed!
